# %%
import os, random
import numpy as np
import tensorflow as tf

SEED=42
os.environ["PYTHONHASHSEED"]=str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

gpus=tf.config.experimental.list_physical_devices("GPU")
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

print("GPU 사용 가능 여부:", tf.config.list_physical_devices("GPU"))

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import backend as K

# Focal Loss
def focal_loss(gamma=2.0, alpha=0.25):
    def loss(y_true, y_pred):
        epsilon=K.epsilon()
        y_pred=K.clip(y_pred, epsilon, 1. - epsilon)
        cross_entropy = -y_true*K.log(y_pred) - (1 - y_true)*K.log(1 - y_pred)
        weight = alpha*y_true*K.pow(1 - y_pred, gamma) + \
                 (1 - alpha)*(1 - y_true)*K.pow(y_pred, gamma)
        return K.mean(weight * cross_entropy, axis=-1)
    return loss

# 제너레이터 
IMG_SIZE=86
BATCH_SIZE=32
DATA_PATH="../../data/processed/02_kaggle_dataset/train"

datagen=ImageDataGenerator(
    rescale=1./255,
    brightness_range=[0.9, 1.1],
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    fill_mode="nearest",
    horizontal_flip=False,
    validation_split=0.2
)

train_generator=datagen.flow_from_directory(
    DATA_PATH,
    target_size=(IMG_SIZE, IMG_SIZE),
    color_mode="grayscale",
    batch_size=BATCH_SIZE,
    class_mode="binary",
    subset="training",
    shuffle=True,
    seed=SEED
)

val_generator=datagen.flow_from_directory(
    DATA_PATH,
    target_size=(IMG_SIZE, IMG_SIZE),
    color_mode="grayscale",
    batch_size=BATCH_SIZE,
    class_mode="binary",
    subset="validation",
    shuffle=False,
    seed=SEED
)

# 모델 정의 -> Dense 128 + Dropout 0.3
model=Sequential([
    Conv2D(64, 3, activation="relu", input_shape=(IMG_SIZE, IMG_SIZE, 1)),
    MaxPooling2D(2),

    Conv2D(96, 3, activation="relu"),
    MaxPooling2D(2),

    Flatten(),
    Dense(128, activation="relu", kernel_regularizer=l2(0.001)),
    Dropout(0.3),
    Dense(1, activation="sigmoid")
])

model.compile(optimizer=Adam(learning_rate=0.0005), loss=focal_loss(gamma=2.0, alpha=0.25), metrics=["accuracy"])
# Out:
# 2025-06-13 17:54:26.761351: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-13 17:54:26.798492: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-06-13 17:54:26.798510: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-06-13 17:54:26.799832: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-13 17:54:26.807584: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-13 17:54:27.684070: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2025-06-13 17:54:28.979421: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-06-13 17:54:29.141860: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-06-13 17:54:29.141909: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# GPU 사용 가능 여부: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Found 38400 images belonging to 2 classes.
# Found 9600 images belonging to 2 classes.
# 2025-06-13 17:54:31.653342: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-06-13 17:54:31.653446: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-06-13 17:54:31.653491: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-06-13 17:54:31.827919: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-06-13 17:54:31.827983: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-06-13 17:54:31.827992: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-06-13 17:54:31.828027: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-06-13 17:54:31.828051: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13689 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Ti, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
history=model.fit(train_generator, validation_data=val_generator, epochs=20, verbose=1)
# Out:
# Epoch 1/20
# 2025-06-13 17:54:39.378193: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2025-06-13 17:54:39.378659: W external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:225] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.9
# 2025-06-13 17:54:39.378698: W external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:228] Used ptxas at ptxas
# 2025-06-13 17:54:39.378768: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:39.499441: W external/local_xla/xla/stream_executor/gpu/redzone_allocator.cc:322] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2025-06-13 17:54:39.904009: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.006657: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.006717: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.007468: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.008370: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.008425: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.008747: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.008819: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.009165: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.010340: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.263083: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.321725: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.321934: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.322115: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.322166: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.323126: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.323173: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.323838: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.323883: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.465238: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.466294: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.466460: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.466490: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.467543: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.467592: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.467995: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.468395: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.579152: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.606489: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.659054: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.685975: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-06-13 17:54:40.709794: I external/local_xla/xla/service/service.cc:168] XLA service 0x70862c01c530 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-06-13 17:54:40.709830: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Ti, Compute Capability 8.9
# 2025-06-13 17:54:40.715243: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-06-13 17:54:40.742651: W external/local_xla/xla/service/gpu/nvptx_compiler.cc:408] Couldn't read CUDA driver version.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1749804880.753425   24319 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1200/1200 [==============================] - 42s 33ms/step - loss: 0.0477 - accuracy: 0.8179 - val_loss: 0.0444 - val_accuracy: 0.7999
# Epoch 2/20
# 1200/1200 [==============================] - 26s 22ms/step - loss: 0.0356 - accuracy: 0.8768 - val_loss: 0.0339 - val_accuracy: 0.8677
# Epoch 3/20
# 1200/1200 [==============================] - 27s 22ms/step - loss: 0.0320 - accuracy: 0.8936 - val_loss: 0.0388 - val_accuracy: 0.8544
# Epoch 4/20
# 1200/1200 [==============================] - 27s 22ms/step - loss: 0.0298 - accuracy: 0.9022 - val_loss: 0.0329 - val_accuracy: 0.8539
# Epoch 5/20
# 1200/1200 [==============================] - 27s 22ms/step - loss: 0.0288 - accuracy: 0.9080 - val_loss: 0.0311 - val_accuracy: 0.8856
# Epoch 6/20
# 1200/1200 [==============================] - 26s 22ms/step - loss: 0.0277 - accuracy: 0.9144 - val_loss: 0.0413 - val_accuracy: 0.8223
# Epoch 7/20
# 1200/1200 [==============================] - 26s 22ms/step - loss: 0.0271 - accuracy: 0.9186 - val_loss: 0.0343 - val_accuracy: 0.8701
# Epoch 8/20
# 1200/1200 [==============================] - 26s 22ms/step - loss: 0.0266 - accuracy: 0.9192 - val_loss: 0.0385 - val_accuracy: 0.8210
# Epoch 9/20
# 1200/1200 [==============================] - 26s 22ms/step - loss: 0.0265 - accuracy: 0.9197 - val_loss: 0.0308 - val_accuracy: 0.8817
# Epoch 10/20
# 1200/1200 [==============================] - 26s 22ms/step - loss: 0.0259 - accuracy: 0.9232 - val_loss: 0.0362 - val_accuracy: 0.8649
# Epoch 11/20
# 1200/1200 [==============================] - 27s 22ms/step - loss: 0.0259 - accuracy: 0.9229 - val_loss: 0.0324 - val_accuracy: 0.8567
# Epoch 12/20
# 1200/1200 [==============================] - 26s 22ms/step - loss: 0.0257 - accuracy: 0.9229 - val_loss: 0.0372 - val_accuracy: 0.8433
# Epoch 13/20
# 1200/1200 [==============================] - 26s 22ms/step - loss: 0.0251 - accuracy: 0.9249 - val_loss: 0.0368 - val_accuracy: 0.8574
# Epoch 14/20
# 1200/1200 [==============================] - 26s 22ms/step - loss: 0.0246 - accuracy: 0.9278 - val_loss: 0.0305 - val_accuracy: 0.8870
# Epoch 15/20
# 1200/1200 [==============================] - 26s 22ms/step - loss: 0.0239 - accuracy: 0.9297 - val_loss: 0.0371 - val_accuracy: 0.8489
# Epoch 16/20
# 1200/1200 [==============================] - 26s 22ms/step - loss: 0.0239 - accuracy: 0.9303 - val_loss: 0.0347 - val_accuracy: 0.8655
# Epoch 17/20
# 1200/1200 [==============================] - 26s 22ms/step - loss: 0.0232 - accuracy: 0.9317 - val_loss: 0.0318 - val_accuracy: 0.8857
# Epoch 18/20
# 1200/1200 [==============================] - 26s 22ms/step - loss: 0.0240 - accuracy: 0.9301 - val_loss: 0.0314 - val_accuracy: 0.8644
# Epoch 19/20
# 1200/1200 [==============================] - 26s 22ms/step - loss: 0.0232 - accuracy: 0.9329 - val_loss: 0.0358 - val_accuracy: 0.8534
# Epoch 20/20
# 1200/1200 [==============================] - 26s 22ms/step - loss: 0.0234 - accuracy: 0.9316 - val_loss: 0.0274 - val_accuracy: 0.9031

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history["accuracy"], label="Train Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title("Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.tight_layout()
plt.savefig("../../results/images/16_dense128_dropout0.3_training_plot.png")
plt.show()


y_true=val_generator.classes
steps=val_generator.samples // val_generator.batch_size + 1
y_pred_prob=model.predict(val_generator, steps=steps, verbose=0)
y_pred=(y_pred_prob > 0.5).astype(int)

report=classification_report(y_true, y_pred, target_names=["closed", "open"])
print(report)

with open("../../results/reports/16_dense128_dropout0.3_classification_report.txt", "w") as f:
    f.write(report)


conf_matrix=confusion_matrix(y_true, y_pred)
plt.figure(figsize=(5, 4))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Reds",
            xticklabels=["closed", "open"], yticklabels=["closed", "open"])
plt.xlabel("Pred")
plt.ylabel("Real")
plt.tight_layout()
plt.savefig("../../results/images/16_dense128_dropout0.3_confusion_matrix.png")
plt.show()
# Out:
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 301 batches). You may need to use the repeat() function when building your dataset.
#               precision    recall  f1-score   support
#
#       closed       0.84      0.98      0.91      4800
#         open       0.98      0.82      0.89      4800
#
#     accuracy                           0.90      9600
#    macro avg       0.91      0.90      0.90      9600
# weighted avg       0.91      0.90      0.90      9600
# 2025-06-13 18:03:46.983196: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 11367941309133853023

# %% [markdown]
# open->closed 오분류: 956->876 감소
#
# 많이 좋지만 여전히 05번 모델이 가장 좋음
# 우선 05번을 기반으로 실시간 예측 진행해보고 안되면 튜닝 진행
